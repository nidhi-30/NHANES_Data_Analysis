# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set directory path
import os
os.chdir("/content/drive/My Drive/COMP-5800-YDK-2020_Group1/MergedData")

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Exploratory Analysis for Hypertension

# %%
hypertensionData = pd.read_csv('HypertensionData.csv')

# %%
hypertensionData.head()
# Out:
#     SEQN  Target  RXQSEEN  RXDDAYS  ...  WHQ040  WHQ190  DLQ040  DLQ020
# 0  93705       1        1     5475  ...     3.0     2.0     2.0     2.0
# 1  93708       1        2     2555  ...     3.0     2.0     2.0     2.0
# 2  93709       1        1      365  ...     2.0     2.0     2.0     2.0
# 3  93714       0        1     4015  ...     2.0     2.0     2.0     2.0
# 4  93715       0        1     4015  ...     3.0     2.0     1.0     1.0
#
# [5 rows x 374 columns]

# %%
hypertensionData.describe()
# Out:
#                 SEQN       Target  ...       DLQ040       DLQ020
# count    2423.000000  2423.000000  ...  2423.000000  2423.000000
# mean    98290.921998     0.679323  ...     1.824829     1.894704
# std      2707.247266     0.466833  ...     0.385493     0.310293
# min     93705.000000     0.000000  ...    -1.000000    -1.000000
# 25%     95888.500000     0.000000  ...     2.000000     2.000000
# 50%     98293.000000     1.000000  ...     2.000000     2.000000
# 75%    100667.000000     1.000000  ...     2.000000     2.000000
# max    102950.000000     1.000000  ...     2.000000     2.000000
#
# [8 rows x 374 columns]

# %%
hypertensionData.corr()
# Out:
#                       SEQN    Target   RXQSEEN  ...    WHQ190    DLQ040    DLQ020
# SEQN              1.000000 -0.044328 -0.011233  ... -0.036371 -0.032966 -0.021694
# Target           -0.044328  1.000000 -0.011202  ...  0.056885  0.101708  0.000905
# RXQSEEN          -0.011233 -0.011202  1.000000  ... -0.006294 -0.033784  0.009399
# RXDDAYS           0.022786  0.043937  0.105914  ...  0.019974 -0.058608 -0.099610
# DRUG_ALLOPURINOL -0.012994 -0.029574 -0.006285  ...  0.002707  0.009235  0.006897
# ...                    ...       ...       ...  ...       ...       ...       ...
# WHQ030           -0.013197 -0.023317 -0.003954  ...  0.085795 -0.016218 -0.008619
# WHQ040           -0.041453  0.027364 -0.003058  ...  0.039271  0.040835  0.007007
# WHQ190           -0.036371  0.056885 -0.006294  ...  1.000000  0.006064 -0.024463
# DLQ040           -0.032966  0.101708 -0.033784  ...  0.006064  1.000000  0.212053
# ...

# %%
hypertensionData['Target'].value_counts()
# Out:
# 1    1646
# 0     777
# Name: Target, dtype: int64

# %%
hypertensionData.RIDAGEYR = hypertensionData.RIDAGEYR.astype(int)
plt.figure(figsize=(18,8))
sns.countplot(x='RIDAGEYR',data=hypertensionData,hue='Target')
plt.xticks(rotation=60)
plt.title('Count of all the Hypertension patients according to age')
plt.xlabel('Age of all the patients')
plt.show()

# %% [markdown]
# From the above graph, it is observed that most of the patients of hypertension are between the age of 60 to 100.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='RIAGENDR',data=hypertensionData,hue='Target')
plt.title('All the patients with Hypertension according to gender')
plt.xlabel('Male = 1.0 and Female = 2.0')
plt.show()

# %% [markdown]
# Gender does not really affect the hypertention disease.

# %%
sns.lineplot(x='RIDAGEYR',y='BMXWT',data=hypertensionData,hue='Target',palette='terrain')
plt.title('Hypertension affected by Weight vs Age')
plt.xlabel('Patient\'s Age')
plt.ylabel('Patient\'s Weight')
plt.show()

# %% [markdown]
# Here, person with weight more than 80 are susceptible to hypertension disease without the age criteria.

# %%
#Patients with Hypertension having Diabetes
hypertensionData.DIQ010 = hypertensionData.DIQ010.astype(int)
plt.figure(figsize=(10,6))
sns.countplot(x='DIQ010',data=hypertensionData,hue='Target')
plt.title('All the patients with Hypertension having Diabetes as well')
plt.xlabel('Have Diabetes = 1, Do not have Diabetes = 2, Borderline = 3')
plt.show()

# %% [markdown]
# There are around 560 people with hypertension are having diabetes as well.

# %%
#Patients with Hypertension having High Cholestrol
hypertensionData.BPQ080 = hypertensionData.BPQ080.astype(int)
plt.figure(figsize=(10,6))
sns.countplot(x='BPQ080',data=hypertensionData,hue='Target')
plt.title('All the patients with Hypertension having High Cholestrol as well')
plt.xlabel('Refused = -1, Have High Cholestrol = 1, Do not have High Cholestrol = 2, Borderline = 3')
plt.show()

# %% [markdown]
# There are 980 people with hypertension are having high cholestrol as well.

# %% [markdown]
# # Exploratory Analysis for Diabetes

# %%
diabetesData = pd.read_csv('DiabetesData.csv')

# %%
diabetesData.head()
# Out:
#     SEQN  Target  RXQSEEN  RXDDAYS  ...  WHQ040  WHQ190  DLQ040  DLQ020
# 0  93705       0        1     5475  ...     3.0     2.0     2.0     2.0
# 1  93708       0        2     2920  ...     3.0     2.0     2.0     2.0
# 2  93709       0        1     2007  ...     2.0     2.0     2.0     2.0
# 3  93714       1        1     4015  ...     2.0     2.0     2.0     2.0
# 4  93715       0        1     4015  ...     3.0     2.0     1.0     1.0
#
# [5 rows x 383 columns]

# %%
diabetesData.describe()
# Out:
#                 SEQN       Target  ...       DLQ040       DLQ020
# count    2423.000000  2423.000000  ...  2423.000000  2423.000000
# mean    98290.921998     0.296740  ...     1.824829     1.894704
# std      2707.247266     0.456915  ...     0.385493     0.310293
# min     93705.000000     0.000000  ...    -1.000000    -1.000000
# 25%     95888.500000     0.000000  ...     2.000000     2.000000
# 50%     98293.000000     0.000000  ...     2.000000     2.000000
# 75%    100667.000000     1.000000  ...     2.000000     2.000000
# max    102950.000000     1.000000  ...     2.000000     2.000000
#
# [8 rows x 383 columns]

# %%
diabetesData.Target.value_counts()
# Out:
# 0    1704
# 1     719
# Name: Target, dtype: int64

# %%
diabetesData.RIDAGEYR = diabetesData.RIDAGEYR.astype(int)
plt.figure(figsize=(18,8))
sns.countplot(x='RIDAGEYR',data=diabetesData,hue='Target')
plt.xticks(rotation=60)
plt.title('Count of all the diabetes patients according to age')
plt.xlabel('Age of all the patients')
plt.show()

# %% [markdown]
# From the above graph, it is observed that most of the people are getting diabetes after the age of 40.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='RIAGENDR',data=diabetesData,hue='Target')
plt.title('All the patients with Diabetes according to gender')
plt.xlabel('Male = 1.0 and Female = 2.0')
plt.show()

# %% [markdown]
# Even in the diabetes, we can see that gender does not really matter for getting diabetes.

# %%
sns.lineplot(x='RIDAGEYR',y='BMXWT',data=diabetesData,hue='Target',palette='terrain')
plt.title('Diabetes affected by Weight vs Age')
plt.xlabel('Patient\'s Age')
plt.ylabel('Patient\'s Weight')
plt.show()

# %% [markdown]
# Most of the people with high weight are having more risk of diabetes. Also, it can be observed that after the age of 50 age does not matter a lot.

# %%
#Patients with Diabetes having High blood pressure
diabetesData.BPQ020 = diabetesData.BPQ020.astype(int)
plt.figure(figsize=(10,6))
sns.countplot(x='BPQ020',data=diabetesData,hue='Target')
plt.title('All the patients with Diabetes having High blood pressure as well')
plt.xlabel('Refused = -1, Have High blood pressure = 1, Do not have High blood pressure = 2')
plt.show()

# %% [markdown]
# Around 500 people with diabetes are having high blood pressure. And one more interesting thing to observe that there is high percentage of people having high blood pressure.

# %%
#Patients with Diabetes having High Cholestrol
diabetesData.BPQ080 = diabetesData.BPQ080.astype(int)
plt.figure(figsize=(10,6))
sns.countplot(x='BPQ080',data=diabetesData,hue='Target')
plt.title('All the patients with Diabetes having High Cholestrol as well')
plt.xlabel('Refused = -1, Have High Cholestrol = 1, Do not have High Cholestrol = 2, Borderline = 3')
plt.show()

# %% [markdown]
# Around 400 people with diabetes are having high cholestrol.

# %% [markdown]
# # Exploratory Analysis for Hypercholesterolemia

# %%
cholestrolData = pd.read_csv('HypercholesterolemiaData.csv')

# %%
cholestrolData.head()
# Out:
#     SEQN  Target  RXQSEEN  RXDDAYS  ...  WHQ040  WHQ190  DLQ040  DLQ020
# 0  93705       0        1     5475  ...     3.0     2.0     2.0     2.0
# 1  93708       1        2     3650  ...     3.0     2.0     2.0     2.0
# 2  93709       0        1     2007  ...     2.0     2.0     2.0     2.0
# 3  93714       0        1     4015  ...     2.0     2.0     2.0     2.0
# 4  93715       1        1     7300  ...     3.0     2.0     1.0     1.0
#
# [5 rows x 366 columns]

# %%
cholestrolData.describe()
# Out:
#                 SEQN       Target  ...       DLQ040       DLQ020
# count    2423.000000  2423.000000  ...  2423.000000  2423.000000
# mean    98290.921998     0.464713  ...     1.824829     1.894704
# std      2707.247266     0.498856  ...     0.385493     0.310293
# min     93705.000000     0.000000  ...    -1.000000    -1.000000
# 25%     95888.500000     0.000000  ...     2.000000     2.000000
# 50%     98293.000000     0.000000  ...     2.000000     2.000000
# 75%    100667.000000     1.000000  ...     2.000000     2.000000
# max    102950.000000     1.000000  ...     2.000000     2.000000
#
# [8 rows x 366 columns]

# %%
cholestrolData['Target'].value_counts()
# Out:
# 0    1297
# 1    1126
# Name: Target, dtype: int64

# %%
cholestrolData.RIDAGEYR = cholestrolData.RIDAGEYR.astype(int)
plt.figure(figsize=(18,8))
sns.countplot(x='RIDAGEYR',data=cholestrolData,hue='Target')
plt.xticks(rotation=60)
plt.title('Count of all the Hypercholestrolemia patients according to age')
plt.xlabel('Age of all the patients')
plt.show()

# %% [markdown]
# Hypercholesterolemia starts after the age of 37. Around 75% people with hypercholesterolemia are having age of 60 and above.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='RIAGENDR',data=cholestrolData,hue='Target')
plt.title('All the patients with Hypercholestrolemia according to gender')
plt.xlabel('Male = 1.0 and Female = 2.0')
plt.show()

# %% [markdown]
# Here also we can see that gender does play crucial role in hypercholesterolemia.

# %%
sns.lineplot(x='RIDAGEYR',y='BMXWT',data=cholestrolData,hue='Target',palette='terrain')
plt.title('Hypercholestrolemia affected by Weight vs Age')
plt.xlabel('Patient\'s Age')
plt.ylabel('Patient\'s Weight')
plt.show()

# %% [markdown]
# Weight and Age are not showing any significant difference for havinh hypercholesterolemia.

# %% [markdown]
# # Exploratory Analysis for Depressive Disorder

# %%
depressionData = pd.read_csv('DepressiveDisorderData.csv')

# %%
depressionData.head()
# Out:
#     SEQN  Target  RXQSEEN  RXDDAYS  ...  WHQ040  WHQ190  DLQ040  DLQ020
# 0  93705       0        1     5475  ...     3.0     2.0     2.0     2.0
# 1  93708       0        2     2920  ...     3.0     2.0     2.0     2.0
# 2  93709       1        1     3650  ...     2.0     2.0     2.0     2.0
# 3  93714       0        1     4015  ...     2.0     2.0     2.0     2.0
# 4  93715       1        1      730  ...     3.0     2.0     1.0     1.0
#
# [5 rows x 378 columns]

# %%
depressionData['Target'].value_counts()
# Out:
# 0    1990
# 1     433
# Name: Target, dtype: int64

# %%
depressionData.RIDAGEYR = depressionData.RIDAGEYR.astype(int)
plt.figure(figsize=(18,8))
sns.countplot(x='RIDAGEYR',data=depressionData,hue='Target')
plt.xticks(rotation=60)
plt.title('Count of all the Depressive disorder patients according to age')
plt.xlabel('Age of all the patients')
plt.show()

# %% [markdown]
# Anyone can have depressive disorder irrelevant to age factor.

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='RIAGENDR',data=depressionData,hue='Target')
plt.title('All the patients with Depressive disorder according to gender')
plt.xlabel('Male = 1.0 and Female = 2.0')
plt.show()

# %% [markdown]
# Females are tend to have more depressive disorder than Males.

# %%
#Patients with Depressive disorder having High sleeplessness
depressionData.DPQ030 = depressionData.DPQ030.astype(int)
plt.figure(figsize=(10,6))
sns.countplot(x='DPQ030',data=depressionData,hue='Target')
plt.title('All the patients with Depressive disorder having sleeplesness as well')
plt.xlabel('Refused = -1, Not at all = 0, Several days = 1, More than half days = 2, Nearly everyday = 3')
plt.show()

# %% [markdown]
# Sleeplesness can be the major factor for depressive disorder. But, because of class imbalance we cannot really pinpoint it.

# %% [markdown]
# # Non-linearity in correlated variables

# %%
#/** Function for removing correlated attributes.
#   dataset - dataframe to find correlation in.
#   threshold - threshold for removing correlated attribute.
#**/
def correlation(dataset, threshold1, threshold2):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold1) and (corr_matrix.iloc[i, j] <= threshold2) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
    #             if colname in dataset.columns:
    #                 del dataset[colname] # deleting the column from the dataset

    # # print(dataset)
    # return dataset
    return col_corr

# %%
 hypertensionData_copy_cols = correlation(hypertensionData, 0.7, 1)
 hypertensionData_copy_cols.add('Target')
 hypertensionData_copy = hypertensionData[hypertensionData_copy_cols]

# %%
len(hypertensionData_copy_cols)
# Out:
# 19

# %%
sns.pairplot(hypertensionData_copy, hue="Target")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
 diabetesData_copy_cols = correlation(diabetesData, 0.7,1)
 diabetesData_copy_cols.add('Target')
 diabetesData_copy = diabetesData[diabetesData_copy_cols]

# %%
diabetesData_copy_cols
# Out:
# {'DXDTOBMC',
#  'DXDTOFAT',
#  'LBDEONO',
#  'LBDTIB',
#  'LBXBGM',
#  'LBXHCT',
#  'LBXHGB',
#  'LBXSASSI',
#  'LBXSCH',
#  'LBXSGL',
#  'LBXSIR',
#  'LBXSNASI',
#  'LBXSTP',
#  'Target',
#  'URDACT',
#  'URDFLOW2',
#  'URXCRS',
#  'URXUMS'}

# %%
sns.pairplot(diabetesData_copy, hue="Target")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
 hypercholesterolemiaData_copy_cols = correlation(cholestrolData, 0.7, 1)
 hypercholesterolemiaData_copy_cols.add('Target')
 hypercholesterolemiaData_copy = cholestrolData[hypercholesterolemiaData_copy_cols]

# %%
sns.pairplot(hypercholesterolemiaData_copy, hue="Target")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
 depressiveDisorderData_copy_cols = correlation(depressionData, 0.7, 1)
 depressiveDisorderData_copy_cols.add('Target')
 depressiveDisorderData_copy = depressionData[depressiveDisorderData_copy_cols]

# %%
sns.pairplot(depressiveDisorderData_copy, hue="Target")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
gastroEsophagealData = pd.read_csv('GastroEsophagealData.csv')

# %%
 gastroEsophagealData_copy_cols = correlation(gastroEsophagealData, 0.7, 1)
 gastroEsophagealData_copy_cols.add('Target')
 gastroEsophagealData_copy = gastroEsophagealData[gastroEsophagealData_copy_cols]

# %%
sns.pairplot(gastroEsophagealData_copy, hue="Target")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
